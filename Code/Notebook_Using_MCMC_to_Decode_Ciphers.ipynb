# %% [markdown]
# ## Using Markov Chain Monte Carlo for Code-Breaking
# _Ec 143, Spring 2026_
# _Bryan S. Graham, UC - Berkeley_
#
# This notebook illustrates how an analyst can use Markov Chain Monte Carlo (MCMC) methods to "crack" a simple substitution cipher. The example is based upon work reaccounted in the paper:
#
# Diaconis, Persi. (2009). "The Markov chain Monte Carlo revolution," _Bulletin of the American Mathematical Society_ 46 (2): 179 - 205.
#
# Some of the code found below was adapted from material found on [this](https://github.com/mattreyes/mcmc-substitution-cipher/tree/master) GitHub repository.
#
# The example is of interest to us for several reasons. First, it provides a novel example of how "thinking like a Bayesian" can help one find solutions to seemingly intractable problems. Second, simulation methods feature widely in modern econometric analysis. Markov Chain Monte Carlo (MCMC) is a leading example. Here we use the foundational Metropolis-Hastings Algorithm. Third, the example highlights connections between stochastic search/optimization and posterior sampling.
#
# While you unlikely to engage in code-breaking as part of your day job as an economists, you may very well utilize the tools employed below in your work.
#
# #### Code citation:
# <br>
# Graham, Bryan S. (2025). "Using Markov Chain Monte Carlo for Code-Breakings Python Jupyter Notebook," (Version 1.0) (Computer program). Available at http://bryangraham.github.io/econometrics/ (Accessed 27 October 2025)

# %%
import re 
from collections import Counter
import random
import numpy as np
import pandas as pd

# %%
def encrypt(plaintext, plaintext_alphabet, cipher_alphabet, blacklist={}):
    
    """
    This function takes a plaintext and returns an encrypted ciphertext.
    
    INPUTS
    ------
    plaintext          : plaintext to be encrypted (string)
    plaintext_alphabet : alphabet of language plain text is written in (list)
    cipher_alphabet    : corresponding alphabet of ciphertext; the mapping from plaintext_alphabet to 
                         cipher_alphabet is one-to-one with the first element of plaintext_alphabet 
                         mapping into the first element of cipher_alphabet etc. (list)
    blacklist          : list of characters that are not encrypted                   
    
    OUTPUTS
    -------
    ciphertext         : encrypted version of plaintext (string)
    
    SOURCES 
    -------
    Some of the code is this function was adapted from material in this GitHub repository:
    
    https://github.com/mattreyes/mcmc-substitution-cipher/tree/master
    
    """
    
    # Check that the plaintext only contains characters in plaintext alphabet. First remove blacklist elements
    # from plaintext, then check that balance of characters can all be found in plaintext_alphabet.
    assert set(list(plaintext)).difference(blacklist).issubset(set(list(plaintext_alphabet))) 
    
    # Check that the cardinality of cipher_alphabet and plaintext_alphabet coincide
    assert len(plaintext_alphabet) == len(cipher_alphabet) 

    # Create a dictionary with the plaintext_alphabet elements as keys and cipher_alphabet elements as values
    encyption_key = dict(zip(list(plaintext_alphabet),list(cipher_alphabet)))
    
    # Encrypt the plaintext
    scc = []                            # initialize list for storing ciphertext
    for l in plaintext:                 # iterate through characters in plaintext
        if l in blacklist:              # leave characters in blacklist "as is" 
            scc += l
        else:                           # swap all other characters using the enc_key dictionary
            scc += [encyption_key[l]]
    ciphertext = "".join(scc)           # convert encrypted ciphertext into a string

    return ciphertext
           

def decrypt(ciphertext, plaintext_alphabet, cipher_alphabet, blacklist={}):
    
    """
    
    This function takes a ciphertext and returns an decrypted plaintext.
    
    INPUTS
    ------
    ciphertext         : ciphertext to be decrypted (string)
    plaintext_alphabet : alphabet of language plain text is written in (list)
    cipher_alphabet    : corresponding alphabet of ciphertext; the mapping from plaintext_alphabet to 
                         cipher_alphabet is one-to-one with the first element of plaintext_alphabet 
                         mapping into the first element of cipher_alphabet etc. (list)
    blacklist          : list of characters that are not encrypted                   
    
    OUTPUTS
    -------
    ciphertext         : encrypted version of plaintext (string)
    
    SOURCES 
    -------
    Some of the code is this function was adapted from material in this GitHub repository:
    
    https://github.com/mattreyes/mcmc-substitution-cipher/tree/master
    
    """
    
    # Create a dictionary with the cipher_alphabet elements as keys and plaintext_alphabet elements as values
    decryption_key = dict(zip(list(cipher_alphabet),list(plaintext_alphabet)))
    
    # decrypt the ciphertext
    scc = []                            # initialize list for storing plaintext
    for l in ciphertext:                # iterate through characters in ciphertext
        if l in blacklist:              # leave characters in blacklist "as is" 
            scc += l
        else:                           # swap all other characters using the dec_key dictionary
            scc += [decryption_key[l]]
    plaintext = "".join(scc)            # convert decrypted ciphertext into a string
    
    return plaintext

# %%
def process_text(filename, regex_ignore='[^A-Z .]'):
    
    """
    This function takes a reference text and returns trigram, bigram and unigram frequences. 
    These can be used to construct a decryption score function.
    
    INPUTS
    ------
    filename       : reference text filename
    regex_ignore   : the default value of '[^A-Z .]' indicates matching with _any_ character that is _not_            
                     uppercase, a space or a period. 
        
    OUTPUTS
    -------

    reference_freq : dictionary of dictionaries with trigram, bigram and unigram frequences found in reference text
    
    SOURCES 
    -------
    Some of the code is this function was adapted from material in this GitHub repository:
    
    https://github.com/mattreyes/mcmc-substitution-cipher/tree/master
    
    """
    
    trigram_counts = Counter()                        # containers for counts of various trigrams,
    bigram_counts  = Counter()                        # bigrams and unigrams
    unigram_counts = Counter()

    # read file which contains reference text
    with open(filename, encoding='unicode_escape') as f:
        
        cnt = 0
        
        # iterate through each line in the file
        for line in f:
            
            # keep track of number of lines read and periodically report status
            cnt += 1         
            if cnt % 1000 == 0: print("{0} lines read.".format(cnt))
            
            # clean up line of text
            if regex_ignore != None:
                pattern = re.compile(regex_ignore)
                s = pattern.sub('',line.upper())      # remove any characters that are not letters, spaces
            else:                                     # or periods and capitalize balance of text.
                s = line.upper()                      

            line_length = len(s)                      # calculate length of line and if it is greater than
                                                      # zero count trigrams, bigrams and unigrams
            if line_length > 0:
                for c in range(line_length-2):
                    trigram_counts[(s[c],s[c+1],s[c+2])] +=1
                    bigram_counts[(s[c],s[c+1])] +=1
                    unigram_counts[s[c]] += 1

                # Add last bigram in the line
                unigram_counts[(s[line_length-2],s[line_length-1])] += 1     
                
                # Add last two unigrams in the line
                unigram_counts[s[line_length-2]] += 1 
                unigram_counts[s[line_length-1]] += 1 
                
    # Convert trigram, bigram and unigram counts into frequencies/probabilities
    total_trigrams = sum(trigram_counts.values())
    total_bigrams  = sum(bigram_counts.values())
    total_unigrams = sum(unigram_counts.values())
            
    pop_trigram_freqs = {}
    for trigram, count in trigram_counts.items():
        pop_trigram_freqs[trigram] = count / total_trigrams
        
    pop_bigram_freqs = {}
    for bigram, count in bigram_counts.items():
        pop_bigram_freqs[bigram] = count / total_bigrams
                
    pop_unigram_freqs = {}
    for unigram, count in unigram_counts.items():
        pop_unigram_freqs[unigram] = count / total_unigrams        

    reference_freqs = {'pop_trigram_freqs': pop_trigram_freqs, 'pop_bigram_freqs': pop_bigram_freqs,\
                      'pop_unigram_freqs': pop_unigram_freqs}
  
    return reference_freqs

# %%
def composite_ciper_logl(ciphertext, plaintext_alphabet, cipher_alphabet, reference_freq, blacklist={}):

    """
    This function constructs the composite log-likelihood for the observed ciphertext based on given
    cipher_alphabet-to-plaintext_alphabet mapping. The composite log-likelihood is constructed based upon
    unigrams, bigrams and trigrams.
    """
    
    trigram_counts = Counter()                        # containers for counts of various trigrams,
    bigram_counts  = Counter()                        # bigrams and unigrams
    unigram_counts = Counter()
    
    epsilon = np.finfo(float).eps
    
    # Decrypt cipertext using current substitution cipher guess
    s = decrypt(ciphertext, plaintext_alphabet, cipher_alphabet, blacklist={})
    message_length = len(s)
    
    # Count tri-, bi- and uni-gram instances in decrypted guess
    for c in range(message_length-2):
        trigram_counts[(s[c],s[c+1],s[c+2])] +=1
        bigram_counts[(s[c],s[c+1])] +=1
        unigram_counts[s[c]] += 1

    # Add last bigram in the line
    unigram_counts[(s[message_length-2],s[message_length-1])] += 1     
                
    # Add last two unigrams in the line
    unigram_counts[s[message_length-2]] += 1 
    unigram_counts[s[message_length-1]] += 1 

    # Construct composite likelihood using trigrams and reference_freq
    clogl_tri = 0
    for trigram, count in trigram_counts.items():
        clogl_tri += count*np.log(reference_freq['pop_trigram_freqs'].setdefault(trigram, epsilon))
        
    # Construct composite likelihood using bigrams and reference_freq
    clogl_bi = 0
    for bigram, count in bigram_counts.items():
        clogl_bi += count*np.log(reference_freq['pop_bigram_freqs'].setdefault(bigram, epsilon))
        
    # Construct composite likelihood using unigrams and reference_freq
    clogl_uni = 0
    for unigram, count in unigram_counts.items():
        clogl_uni += count*np.log(reference_freq['pop_unigram_freqs'].setdefault(unigram, epsilon))
      
    return {'clogl_tri' : clogl_tri, 'clogl_bi' : clogl_bi, 'clogl_uni' : clogl_uni}

# %%
# Directory where Dune text file is located
data =  '/Users/bgraham/Dropbox/Teaching/Berkeley_Courses/Ec143/Ec143_Spring2026/Data/'

# %%
dune_freq = process_text(data+'Dune.txt')
# Out:
# 1000 lines read.
# 2000 lines read.
# 3000 lines read.
# 4000 lines read.
# 5000 lines read.
# 6000 lines read.
# 7000 lines read.
# 8000 lines read.

# %%
# Define and clean message
message = "I must not fear. Fear is the mind-killer. Fear is the little-death that brings total obliteration. I will face my fear. I will permit it to pass over me and through me. And when it has gone past I will turn the inner eye to see its path. Where the fear has gone there will be nothing. Only I will remain."
ignore_list = '[^A-Z .]'
pattern = re.compile(ignore_list)
message_cleaned = pattern.sub('',message.upper())
message_cleaned

# Encrypt message using a randomly chosen simpler substitution cipher
english_alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ ."       # define plaintext alphabet
tmp = list(english_alphabet)                            # turn it into a list and randomly shuffle
random.shuffle(tmp)
cipher_alphabet = "".join(tmp)                          # define ciphertext alphabet
message_encrypted = encrypt(message_cleaned, english_alphabet, cipher_alphabet)

print("")
print("Original (cleaned) message:  ")
print("-----------------------------")
print(message_cleaned)
print("")
print("Encrypted message:           ")
print("-----------------------------")
print(message_encrypted)


# true decryption key
dec_key = dict(zip(list(cipher_alphabet),list(english_alphabet)))
print("")
print("Simple substitution cipher:  ")
print("-----------------------------")
print(dec_key)
# Out:
# Original (cleaned) message:
# -----------------------------
# I MUST NOT FEAR. FEAR IS THE MINDKILLER. FEAR IS THE LITTLEDEATH THAT BRINGS TOTAL OBLITERATION. I WILL FACE MY FEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE FEAR HAS GONE THERE WILL BE NOTHING. ONLY I WILL REMAIN.
#
# Encrypted message:
# -----------------------------
# AXZKJCXW.CXRVGLNXRVGLXAJXCPVXZAWYHAFFVLNXRVGLXAJXCPVXFACCFVYVGCPXCPGCX LAWEJXC.CGFX. FACVLGCA.WNXAXTAFFXRGMVXZSXRVGLNXAXTAFFXOVLZACXACXC.XOGJJX.BVLXZVXGWYXCPL.KEPXZVNXGWYXTPVWXACXPGJXE.WVXOGJCXAXTAFFXCKLWXCPVXAWWVLXVSVXC.XJVVXACJXOGCPNXTPVLVXCPVXRVGLXPGJXE.WVXCPVLVXTAFFX VXW.CPAWENX.WFSXAXTAFFXLVZGAWN
#
# Simple substitution cipher:
# -----------------------------
# {'G': 'A', ' ': 'B', 'M': 'C', 'Y': 'D', 'V': 'E', 'R': 'F', 'E': 'G', 'P': 'H', 'A': 'I', 'U': 'J', 'H': 'K', 'F': 'L', 'Z': 'M', 'W': 'N', '.': 'O', 'O': 'P', 'I': 'Q', 'L': 'R', 'J': 'S', 'C': 'T', 'K': 'U', 'B': 'V', 'T': 'W', 'D': 'X', 'S': 'Y', 'Q': 'Z', 'X': ' ', 'N': '.'}

# %% [markdown]
# ## Cracking an encrypted message

# %%
print("")
print("Encrypted message:           ")
print("-----------------------------")
print(message_encrypted)
# Out:
# Encrypted message:
# -----------------------------
# AXZKJCXW.CXRVGLNXRVGLXAJXCPVXZAWYHAFFVLNXRVGLXAJXCPVXFACCFVYVGCPXCPGCX LAWEJXC.CGFX. FACVLGCA.WNXAXTAFFXRGMVXZSXRVGLNXAXTAFFXOVLZACXACXC.XOGJJX.BVLXZVXGWYXCPL.KEPXZVNXGWYXTPVWXACXPGJXE.WVXOGJCXAXTAFFXCKLWXCPVXAWWVLXVSVXC.XJVVXACJXOGCPNXTPVLVXCPVXRVGLXPGJXE.WVXCPVLVXTAFFX VXW.CPAWENX.WFSXAXTAFFXLVZGAWN

# %%
plaintext_alphabet = english_alphabet
reference_freq = dune_freq
ciphertext = message_encrypted
iters = 100000

# Counter for the number of accepted swaps
accepted_swaps = 0

# Dictionary to store MCMC output
mcmc_output = {'s' : [], 'log_likelihood' : [], 'cipher' : []}

# initial cipher key guess (random) and likelihood value
tmp = list(plaintext_alphabet)   
random.shuffle(tmp)
current_plaintext_alphabet_guess = "".join(tmp)  
logL_s = composite_ciper_logl(ciphertext, current_plaintext_alphabet_guess, cipher_alphabet, reference_freq)

# current current cipher key
current_decryption_key = dict(zip(list(cipher_alphabet),list(current_plaintext_alphabet_guess)))

# add initial values to dictionary
mcmc_output['s'].append(0)
mcmc_output['log_likelihood'].append(logL_s['clogl_bi'])
mcmc_output['cipher'].append(current_decryption_key)

for s in range(0,iters):
   
    # generate proposal cipher by swapping two characters in current cipher
    a, b = np.random.choice(list(cipher_alphabet), 2, replace=True)
    proposed_decryption_key    = current_decryption_key.copy()
    proposed_decryption_key[a] = current_decryption_key[b]
    proposed_decryption_key[b] = current_decryption_key[a]
    proposed_plaintext_alphabet_guess = "".join(list(proposed_decryption_key.values()))


    # compute difference in current and proposed composite logL
    logL_proposed = composite_ciper_logl(ciphertext, proposed_plaintext_alphabet_guess, cipher_alphabet, reference_freq)
    log_alpha = logL_proposed['clogl_bi'] - logL_s['clogl_bi']

    # Decide to accept new proposal
    V = np.random.exponential(scale=1.0)
    if V >= -log_alpha:
        logL_s = logL_proposed
        current_plaintext_alphabet_guess = proposed_plaintext_alphabet_guess
        current_decryption_key = dict(zip(list(cipher_alphabet),list(proposed_plaintext_alphabet_guess)))
        accepted_swaps += 1
    
    # add current iteration of output to dictionary
    mcmc_output['s'].append(s)
    mcmc_output['log_likelihood'].append(logL_s['clogl_bi'])
    mcmc_output['cipher'].append(current_decryption_key)

    # Print out progress
    if s % 500 == 0: 
        print("")
        print("iter:", s, decrypt(ciphertext, current_plaintext_alphabet_guess, cipher_alphabet, blacklist={}))
# Out:
# iter: 0 EVDL HVASHVRJQW.VRJQWVE VHPJVDEATCEFFJW.VRJQWVE VHPJVFEHHFJTJQHPVHPQHVIWEAZ VHSHQFVSIFEHJWQHESA.VEVGEFFVRQKJVDMVRJQW.VEVGEFFVYJWDEHVEHVHSVYQ  VSXJWVDJVQATVHPWSLZPVDJ.VQATVGPJAVEHVPQ VZSAJVYQ HVEVGEFFVHLWAVHPJVEAAJWVJMJVHSV JJVEH VYQHP.VGPJWJVHPJVRJQWVPQ VZSAJVHPJWJVGEFFVIJVASHPEAZ.VSAFMVEVGEFFVWJDQEA.
#
# iter: 500 A WKRS MUS BEONT BEON AR SIE WAMP.ALLENT BEON AR SIE LASSLEPEOSI SIOS GNAMYR SUSOL UGLASENOSAUMT A CALL BOVE WH BEONT A CALL FENWAS AS SU FORR UDEN WE OMP SINUKYI WET OMP CIEM AS IOR YUME FORS A CALL SKNM SIE AMMEN EHE SU REE ASR FOSIT CIENE SIE BEON IOR YUME SIENE CALL GE MUSIAMYT UMLH A CALL NEWOAMT
#
# iter: 1000 A CYDS RIS WEONG WEON AD STE CARMPALLENG WEON AD STE LASSLEMEOST STOS KNARUD SISOL IKLASENOSAIRG A HALL WOVE C. WEONG A HALL FENCAS AS SI FODD IBEN CE ORM STNIYUT CEG ORM HTER AS TOD UIRE FODS A HALL SYNR STE ARREN E.E SI DEE ASD FOSTG HTENE STE WEON TOD UIRE STENE HALL KE RISTARUG IRL. A HALL NECOARG
#
# iter: 1500 A CUDS ROS HEING HEIN AD STE CARMBALLENG HEIN AD STE LASSLEMEIST STIS FNARYD SOSIL OFLASENISAORG A PALL HIVE C. HEING A PALL WENCAS AS SO WIDD OKEN CE IRM STNOUYT CEG IRM PTER AS TID YORE WIDS A PALL SUNR STE ARREN E.E SO DEE ASD WISTG PTENE STE HEIN TID YORE STENE PALL FE ROSTARYG ORL. A PALL NECIARG
#
# iter: 2000 A CUDS ROS HEING HEIN AD STE CARMBALLENG HEIN AD STE LASSLEMEIST STIS WNARYD SOSIL OWLASENISAORG A PALL HIVE C. HEING A PALL FENCAS AS SO FIDD OKEN CE IRM STNOUYT CEG IRM PTER AS TID YORE FIDS A PALL SUNR STE ARREN E.E SO DEE ASD FISTG PTENE STE HEIN TID YORE STENE PALL WE ROSTARYG ORL. A PALL NECIARG
#
# iter: 2500 A CUDS ROS HEING HEIN AD STE CARMBALLENG HEIN AD STE LASSLEMEIST STIS FNARYD SOSIL OFLASENISAORG A PALL HIVE C. HEING A PALL WENCAS AS SO WIDD OKEN CE IRM STNOUYT CEG IRM PTER AS TID YORE WIDS A PALL SUNR STE ARREN E.E SO DEE ASD WISTG PTENE STE HEIN TID YORE STENE PALL FE ROSTARYG ORL. A PALL NECIARG
#
# iter: 3000 A FUDS ROS HEING HEIN AD STE FARMPALLENG HEIN AD STE LASSLEMEIST STIS KNARYD SOSIL OKLASENISAORG A CALL HIVE F. HEING A CALL WENFAS AS SO WIDD OBEN FE IRM STNOUYT FEG IRM CTER AS TID YORE WIDS A CALL SUNR STE ARREN E.E SO DEE ASD WISTG CTENE STE HEIN TID YORE STENE CALL KE ROSTARYG ORL. A CALL NEFIARG
#
# iter: 3500 A FUDS ROS HEING HEIN AD STE FARMPALLENG HEIN AD STE LASSLEMEIST STIS KNARYD SOSIL OKLASENISAORG A CALL HIVE F. HEING A CALL WENFAS AS SO WIDD OBEN FE IRM STNOUYT FEG IRM CTER AS TID YORE WIDS A CALL SUNR STE ARREN E.E SO DEE ASD WISTG CTENE STE HEIN TID YORE STENE CALL KE ROSTARYG ORL. A CALL NEFIARG
#
# iter: 4000 A FUDS ROS HEING HEIN AD STE FARMBALLENG HEIN AD STE LASSLEMEIST STIS PNARYD SOSIL OPLASENISAORG A CALL HIVE F. HEING A CALL WENFAS AS SO WIDD OKEN FE IRM STNOUYT FEG IRM CTER AS TID YORE WIDS A CALL SUNR STE ARREN E.E SO DEE ASD WISTG CTENE STE HEIN TID YORE STENE CALL PE ROSTARYG ORL. A CALL NEFIARG
#
# iter: 4500 A CUDS ROS HEING HEIN AD STE CARMBALLENG HEIN AD STE LASSLEMEIST STIS FNARYD SOSIL OFLASENISAORG A PALL HIVE C. HEING A PALL WENCAS AS SO WIDD OKEN CE IRM STNOUYT CEG IRM PTER AS TID YORE WIDS A PALL SUNR STE ARREN E.E SO DEE ASD WISTG PTENE STE HEIN TID YORE STENE PALL FE ROSTARYG ORL. A PALL NECIARG
#
# iter: 5000 A CUNS ROS HEID. HEID AN STE CARMBALLED. HEID AN STE LASSLEMEIST STIS FDARYN SOSIL OFLASEDISAOR. A PALL HIVE CK HEID. A PALL WEDCAS AS SO WINN OJED CE IRM STDOUYT CE. IRM PTER AS TIN YORE WINS A PALL SUDR STE ARRED EKE SO NEE ASN WIST. PTEDE STE HEID TIN YORE STEDE PALL FE ROSTARY. ORLK A PALL DECIAR.
#
# iter: 5500 A CUNS ROS HEID. HEID AN STE CARMBALLED. HEID AN STE LASSLEMEIST STIS FDARYN SOSIL OFLASEDISAOR. A PALL HIVE CK HEID. A PALL WEDCAS AS SO WINN OGED CE IRM STDOUYT CE. IRM PTER AS TIN YORE WINS A PALL SUDR STE ARRED EKE SO NEE ASN WIST. PTEDE STE HEID TIN YORE STEDE PALL FE ROSTARY. ORLK A PALL DECIAR.
#
# iter: 6000 A CUNT ROT HEID. HEID AN TSE CARKBALLED. HEID AN TSE LATTLEKEITS TSIT FDARMN TOTIL OFLATEDITAOR. A PALL HIGE CY HEID. A PALL WEDCAT AT TO WINN OVED CE IRK TSDOUMS CE. IRK PSER AT SIN MORE WINT A PALL TUDR TSE ARRED EYE TO NEE ATN WITS. PSEDE TSE HEID SIN MORE TSEDE PALL FE ROTSARM. ORLY A PALL DECIAR.
#
# iter: 6500 A CUNT ROT HEID. HEID AN TSE CARYVALLED. HEID AN TSE LATTLEYEITS TSIT PDARMN TOTIL OPLATEDITAOR. A WALL HIGE CK HEID. A WALL FEDCAT AT TO FINN OBED CE IRY TSDOUMS CE. IRY WSER AT SIN MORE FINT A WALL TUDR TSE ARRED EKE TO NEE ATN FITS. WSEDE TSE HEID SIN MORE TSEDE WALL PE ROTSARM. ORLK A WALL DECIAR.
#
# iter: 7000 A CUNT ROT MEID. MEID AN THE CARYVALLED. MEID AN THE LATTLEYEITH THIT BDARSN TOTIL OBLATEDITAOR. A WALL MIGE CK MEID. A WALL PEDCAT AT TO PINN OFED CE IRY THDOUSH CE. IRY WHER AT HIN SORE PINT A WALL TUDR THE ARRED EKE TO NEE ATN PITH. WHEDE THE MEID HIN SORE THEDE WALL BE ROTHARS. ORLK A WALL DECIAR.
#
# iter: 7500 I CURT NOT BEAD. BEAD IR THE CINYVILLED. BEAD IR THE LITTLEYEATH THAT PDINSR TOTAL OPLITEDATION. I WILL BAGE CK BEAD. I WILL MEDCIT IT TO MARR OFED CE ANY THDOUSH CE. ANY WHEN IT HAR SONE MART I WILL TUDN THE INNED EKE TO REE ITR MATH. WHEDE THE BEAD HAR SONE THEDE WILL PE NOTHINS. ONLK I WILL DECAIN.
#
# iter: 8000 I MURT NOT BEAD. BEAD IR THE MINCKISSED. BEAD IR THE SITTSECEATH THAT LDINGR TOTAS OLSITEDATION. I WISS BAYE MP BEAD. I WISS FEDMIT IT TO FARR OJED ME ANC THDOUGH ME. ANC WHEN IT HAR GONE FART I WISS TUDN THE INNED EPE TO REE ITR FATH. WHEDE THE BEAD HAR GONE THEDE WISS LE NOTHING. ONSP I WISS DEMAIN.
#
# iter: 8500 I MURT NOT BEAD. BEAD IR THE MINCKISSED. BEAD IR THE SITTSECEATH THAT LDINGR TOTAS OLSITEDATION. I WISS BAVE MY BEAD. I WISS PEDMIT IT TO PARR OJED ME ANC THDOUGH ME. ANC WHEN IT HAR GONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR GONE THEDE WISS LE NOTHING. ONSY I WISS DEMAIN.
#
# iter: 9000 I MURT NOT BEAD. BEAD IR THE MINCKISSED. BEAD IR THE SITTSECEATH THAT LDINGR TOTAS OLSITEDATION. I WISS BAVE MY BEAD. I WISS PEDMIT IT TO PARR OFED ME ANC THDOUGH ME. ANC WHEN IT HAR GONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR GONE THEDE WISS LE NOTHING. ONSY I WISS DEMAIN.
#
# iter: 9500 I MURT NOT BEAD. BEAD IR THE MINGFISSED. BEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS BAKE MY BEAD. I WISS PEDMIT IT TO PARR OVED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 10000 I MURT NOT BEAD. BEAD IR THE MINGFISSED. BEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS BAKE MY BEAD. I WISS PEDMIT IT TO PARR OVED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 10500 I MURT NOT BEAD. BEAD IR THE MINGFISSED. BEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS BAVE MY BEAD. I WISS PEDMIT IT TO PARR OKED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 11000 I MURT NOT BEAD. BEAD IR THE MINGFISSED. BEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS BAVE MY BEAD. I WISS PEDMIT IT TO PARR OKED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 11500 I MURT NOT BEAD. BEAD IR THE MINGFISSED. BEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS BAKE MY BEAD. I WISS PEDMIT IT TO PARR OVED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 12000 I MURT NOT BEAD. BEAD IR THE MINGFISSED. BEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS BAKE MY BEAD. I WISS PEDMIT IT TO PARR OVED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 12500 I MURT NOT PEAD. PEAD IR THE MINGKISSED. PEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS PAVE MY PEAD. I WISS BEDMIT IT TO BARR OFED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE BART I WISS TUDN THE INNED EYE TO REE ITR BATH. WHEDE THE PEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 13000 I MURT NOT BEAD. BEAD IR THE MINGFISSED. BEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS BAKE MY BEAD. I WISS PEDMIT IT TO PARR OVED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 13500 I MURT NOT BEAD. BEAD IR THE MINGFISSED. BEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS BAVE MY BEAD. I WISS PEDMIT IT TO PARR OKED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 14000 I MURT NOT BEAD. BEAD IR THE MINGFISSED. BEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS BAVE MY BEAD. I WISS PEDMIT IT TO PARR OKED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
# iter: 14500 I MURT NOT PEAD. PEAD IR THE MINGKISSED. PEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS PAVE MY PEAD. I WISS BEDMIT IT TO BARR OFED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE BART I WISS TUDN THE INNED EYE TO REE ITR BATH. WHEDE THE PEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 15000 I MURT NOT PEAD. PEAD IR THE MINCKISSED. PEAD IR THE SITTSECEATH THAT LDINGR TOTAS OLSITEDATION. I WISS PAVE MY PEAD. I WISS BEDMIT IT TO BARR OFED ME ANC THDOUGH ME. ANC WHEN IT HAR GONE BART I WISS TUDN THE INNED EYE TO REE ITR BATH. WHEDE THE PEAD HAR GONE THEDE WISS LE NOTHING. ONSY I WISS DEMAIN.
#
# iter: 15500 I MURT NOT BEAD. BEAD IR THE MINCKISSED. BEAD IR THE SITTSECEATH THAT LDINGR TOTAS OLSITEDATION. I WISS BAVE MY BEAD. I WISS PEDMIT IT TO PARR OFED ME ANC THDOUGH ME. ANC WHEN IT HAR GONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR GONE THEDE WISS LE NOTHING. ONSY I WISS DEMAIN.
#
# iter: 16000 I MURT NOT BEAD. BEAD IR THE MINGFISSED. BEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS BAKE MY BEAD. I WISS PEDMIT IT TO PARR OVED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 16500 I MURT NOT PEAD. PEAD IR THE MINGFISSED. PEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS PAKE MY PEAD. I WISS BEDMIT IT TO BARR OVED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE BART I WISS TUDN THE INNED EYE TO REE ITR BATH. WHEDE THE PEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 17000 I MURT NOT BEAD. BEAD IR THE MINGFISSED. BEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS BAKE MY BEAD. I WISS PEDMIT IT TO PARR OVED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 17500 I MURT NOT BEAD. BEAD IR THE MINCKISSED. BEAD IR THE SITTSECEATH THAT LDINGR TOTAS OLSITEDATION. I WISS BAVE MY BEAD. I WISS PEDMIT IT TO PARR OFED ME ANC THDOUGH ME. ANC WHEN IT HAR GONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR GONE THEDE WISS LE NOTHING. ONSY I WISS DEMAIN.
#
# iter: 18000 I MURT NOT BEAD. BEAD IR THE MINGKISSED. BEAD IR THE SITTSEGEATH THAT LDINCR TOTAS OLSITEDATION. I WISS BAVE MY BEAD. I WISS PEDMIT IT TO PARR OFED ME ANG THDOUCH ME. ANG WHEN IT HAR CONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE BEAD HAR CONE THEDE WISS LE NOTHINC. ONSY I WISS DEMAIN.
#
# iter: 18500 I MURT NOT FEAD. FEAD IR THE MINLKISSED. FEAD IR THE SITTSELEATH THAT YDINGR TOTAS OYSITEDATION. I WISS FABE MP FEAD. I WISS CEDMIT IT TO CARR OVED ME ANL THDOUGH ME. ANL WHEN IT HAR GONE CART I WISS TUDN THE INNED EPE TO REE ITR CATH. WHEDE THE FEAD HAR GONE THEDE WISS YE NOTHING. ONSP I WISS DEMAIN.
#
# iter: 19000 I MURT NOT BEAD. BEAD IR THE MINLFISSED. BEAD IR THE SITTSELEATH THAT PDINGR TOTAS OPSITEDATION. I WISS BAKE MY BEAD. I WISS CEDMIT IT TO CARR OVED ME ANL THDOUGH ME. ANL WHEN IT HAR GONE CART I WISS TUDN THE INNED EYE TO REE ITR CATH. WHEDE THE BEAD HAR GONE THEDE WISS PE NOTHING. ONSY I WISS DEMAIN.
#
# iter: 19500 I MURT NOT BEAD. BEAD IR THE MINLFISSED. BEAD IR THE SITTSELEATH THAT PDINGR TOTAS OPSITEDATION. I WISS BAKE MY BEAD. I WISS CEDMIT IT TO CARR OVED ME ANL THDOUGH ME. ANL WHEN IT HAR GONE CART I WISS TUDN THE INNED EYE TO REE ITR CATH. WHEDE THE BEAD HAR GONE THEDE WISS PE NOTHING. ONSY I WISS DEMAIN.
#
# iter: 20000 I MURT NOT CEAD. CEAD IR THE MINLFISSED. CEAD IR THE SITTSELEATH THAT BDINGR TOTAS OBSITEDATION. I WISS CAKE MY CEAD. I WISS PEDMIT IT TO PARR OVED ME ANL THDOUGH ME. ANL WHEN IT HAR GONE PART I WISS TUDN THE INNED EYE TO REE ITR PATH. WHEDE THE CEAD HAR GONE THEDE WISS BE NOTHING. ONSY I WISS DEMAIN.
#
# iter: 20500 I MURT NOT BEAD. BEAD IR THE MINLFISSED. BEAD IR THE SITTSELEATH THAT PDINGR TOTAS OPSITEDATION. I WISS BAVE MY BEAD. I WISS CEDMIT IT TO CARR OKED ME ANL THDOUGH ME. ANL WHEN IT HAR GONE CART I WISS TUDN THE INNED EYE TO REE ITR CATH. WHEDE THE BEAD HAR GONE THEDE WISS PE NOTHING. ONSY I WISS DEMAIN.
#
# iter: 21000 I MURT NOT PEAD. PEAD IR THE MINLFISSED. PEAD IR THE SITTSELEATH THAT BDINGR TOTAS OBSITEDATION. I WISS PAKE MY PEAD. I WISS CEDMIT IT TO CARR OVED ME ANL THDOUGH ME. ANL WHEN IT HAR GONE CART I WISS TUDN THE INNED EYE TO REE ITR CATH. WHEDE THE PEAD HAR GONE THEDE WISS BE NOTHING. ONSY I WISS DEMAIN.
#
# iter: 21500 I MUDT NOT BEAR. BEAR ID THE MINSPILLER. BEAR ID THE LITTLESEATH THAT FRINGD TOTAL OFLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CADD OKER ME ANS THROUGH ME. ANS WHEN IT HAD GONE CADT I WILL TURN THE INNER EYE TO DEE ITD CATH. WHERE THE BEAR HAD GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 22000 I MULT NOT BEAR. BEAR IL THE MINDKISSER. BEAR IL THE SITTSEDEATH THAT FRINGL TOTAS OFSITERATION. I WISS BAPE MY BEAR. I WISS CERMIT IT TO CALL OVER ME AND THROUGH ME. AND WHEN IT HAL GONE CALT I WISS TURN THE INNER EYE TO LEE ITL CATH. WHERE THE BEAR HAL GONE THERE WISS FE NOTHING. ONSY I WISS REMAIN.
#
# iter: 22500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAPE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 23000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 23500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 24000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 24500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 25000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 25500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 26000 I MUST NOT BEAR. BEAR IS THE MINDCILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 26500 I MUST NOT CEAR. CEAR IS THE MINDPILLER. CEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL CAKE MY CEAR. I WILL BERMIT IT TO BASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 27000 I MUST NOT BEAR. BEAR IS THE MINDCILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 27500 I CUST NOT BEAR. BEAR IS THE CINDMILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE CY BEAR. I WILL PERCIT IT TO PASS OVER CE AND THROUGH CE. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL RECAIN.
#
# iter: 28000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 28500 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 29000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
# iter: 29500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OCER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 30000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 30500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 31000 I MUST NOT BEAR. BEAR IS THE MINDFILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 31500 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 32000 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 32500 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL CAKE MY CEAR. I WILL FERMIT IT TO FASS OBER ME AND THROUGH ME. AND WHEN IT HAS GONE FAST I WILL TURN THE INNER EYE TO SEE ITS FATH. WHERE THE CEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 33000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAFE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 33500 I MUST NOT BEAR. BEAR IS THE MINDJILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 34000 I MUST NOT BEAR. BEAR IS THE MINDJILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 34500 I MUST NOT BEAR. BEAR IS THE MINDJILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 35000 I MUST NOT BEAR. BEAR IS THE MINDJILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 35500 I MUST NOT BEAR. BEAR IS THE MINDFILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 36000 I MUST NOT CEAR. CEAR IS THE MINDFILLER. CEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL CAKE MY CEAR. I WILL BERMIT IT TO BASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 36500 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL CAKE MY CEAR. I WILL BERMIT IT TO BASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 37000 I MUST NOT BEAR. BEAR IS THE MINDFILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 37500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 38000 I MUST NOT CEAR. CEAR IS THE MINDFILLER. CEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL CAVE MY CEAR. I WILL BERMIT IT TO BASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 38500 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL CAKE MY CEAR. I WILL BERMIT IT TO BASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 39000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 39500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 40000 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT BRINGS TOTAL OBLITERATION. I WILL CAKE MY CEAR. I WILL PERMIT IT TO PASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE CEAR HAS GONE THERE WILL BE NOTHING. ONLY I WILL REMAIN.
#
# iter: 40500 I MUST NOT BEAR. BEAR IS THE MINDFILLER. BEAR IS THE LITTLEDEATH THAT CRINGS TOTAL OCLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL CE NOTHING. ONLY I WILL REMAIN.
#
# iter: 41000 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL CAKE MY CEAR. I WILL BERMIT IT TO BASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 41500 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL CAKE MY CEAR. I WILL PERMIT IT TO PASS OBER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE CEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 42000 I MUST NOT CEAR. CEAR IS THE MINDBILLER. CEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL CAKE MY CEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE CEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 42500 I MUST NOT BEAR. BEAR IS THE MINDGILLER. BEAR IS THE LITTLEDEATH THAT FRINCS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUCH ME. AND WHEN IT HAS CONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS CONE THERE WILL FE NOTHINC. ONLY I WILL REMAIN.
#
# iter: 43000 I MUST NOT CEAR. CEAR IS THE MINDFILLER. CEAR IS THE LITTLEDEATH THAT BRINGS TOTAL OBLITERATION. I WILL CAKE MY CEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE CEAR HAS GONE THERE WILL BE NOTHING. ONLY I WILL REMAIN.
#
# iter: 43500 I MUST NOT CEAR. CEAR IS THE MINDFILLER. CEAR IS THE LITTLEDEATH THAT BRINGS TOTAL OBLITERATION. I WILL CAKE MY CEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE CEAR HAS GONE THERE WILL BE NOTHING. ONLY I WILL REMAIN.
#
# iter: 44000 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 44500 I MUST NOT BEAR. BEAR IS THE MINDJILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 45000 I MUST NOT BEAR. BEAR IS THE MINDFILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
# iter: 45500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 46000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 46500 I MUST NOT BEAR. BEAR IS THE MINDCILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 47000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 47500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 48000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 48500 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 49000 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 49500 I MUST NOT BEAR. BEAR IS THE MINDJILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BACE MY BEAR. I WILL FERMIT IT TO FASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE FAST I WILL TURN THE INNER EYE TO SEE ITS FATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 50000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 50500 I MUST NOT BEAR. BEAR IS THE MINDFILLER. BEAR IS THE LITTLEDEATH THAT CRINGS TOTAL OCLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL CE NOTHING. ONLY I WILL REMAIN.
#
# iter: 51000 I MUST NOT BEAR. BEAR IS THE MINDCILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 51500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 52000 I MUST NOT BEAR. BEAR IS THE MINDCILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 52500 I MUST NOT BEAR. BEAR IS THE MINDPILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 53000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT CRINGS TOTAL OCLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL CE NOTHING. ONLY I WILL REMAIN.
#
# iter: 53500 I MUST NOT BEAR. BEAR IS THE MINDFILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 54000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 54500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAFE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 55000 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL CAFE MY CEAR. I WILL BERMIT IT TO BASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 55500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 56000 I MUST NOT PEAR. PEAR IS THE MINDVILLER. PEAR IS THE LITTLEDEATH THAT BRINGS TOTAL OBLITERATION. I WILL PAKE MY PEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE PEAR HAS GONE THERE WILL BE NOTHING. ONLY I WILL REMAIN.
#
# iter: 56500 I MUST NOT BEAR. BEAR IS THE MINDJILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 57000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 57500 I MUST NOT BEAR. BEAR IS THE MINDJILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAVE MY BEAR. I WILL PERMIT IT TO PASS OCER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 58000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 58500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAFE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 59000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 59500 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 60000 I MUST NOT FEAR. FEAR IS THE MINDBILLER. FEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL FAVE MY FEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE FEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 60500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 61000 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL CAPE MY CEAR. I WILL BERMIT IT TO BASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 61500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 62000 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 62500 I MUST NOT BEAR. BEAR IS THE MINDFILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 63000 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL CAKE MY CEAR. I WILL PERMIT IT TO PASS OBER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE CEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 63500 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 64000 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 64500 I MUST NOT BEAR. BEAR IS THE MINDCILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 65000 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL CAKE MY CEAR. I WILL BERMIT IT TO BASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 65500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 66000 I MUST NOT BEAR. BEAR IS THE MINDCILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 66500 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 67000 I MUST NOT PEAR. PEAR IS THE MINDVILLER. PEAR IS THE LITTLEDEATH THAT BRINGS TOTAL OBLITERATION. I WILL PAKE MY PEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE PEAR HAS GONE THERE WILL BE NOTHING. ONLY I WILL REMAIN.
# iter: 67500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAPE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 68000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 68500 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 69000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 69500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAPE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 70000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BACE MY BEAR. I WILL FERMIT IT TO FASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE FAST I WILL TURN THE INNER EYE TO SEE ITS FATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 70500 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL CABE MY CEAR. I WILL PERMIT IT TO PASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE CEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 71000 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL CAKE MY CEAR. I WILL BERMIT IT TO BASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 71500 I MUST NOT BEAR. BEAR IS THE MINDJILLER. BEAR IS THE LITTLEDEATH THAT CRINGS TOTAL OCLITERATION. I WILL BAVE MY BEAR. I WILL PERMIT IT TO PASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL CE NOTHING. ONLY I WILL REMAIN.
#
# iter: 72000 I MUST NOT PEAR. PEAR IS THE MINDJILLER. PEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL PAVE MY PEAR. I WILL BERMIT IT TO BASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE PEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 72500 I MUST NOT BEAR. BEAR IS THE MINDCILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 73000 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 73500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OCER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 74000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 74500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 75000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 75500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 76000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 76500 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL CAKE MY CEAR. I WILL PERMIT IT TO PASS OBER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE CEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 77000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAPE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 77500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 78000 I MUST NOT PEAR. PEAR IS THE MINDVILLER. PEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL PABE MY PEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE PEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 78500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAPE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 79000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAJE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 79500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 80000 I MUST NOT BEAR. BEAR IS THE MINDFILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 80500 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 81000 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 81500 I MUST NOT BEAR. BEAR IS THE MINDCILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 82000 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL CAPE MY CEAR. I WILL BERMIT IT TO BASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 82500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 83000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
# iter: 83500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 84000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 84500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAPE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 85000 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT CRINGS TOTAL OCLITERATION. I WILL BAPE MY BEAR. I WILL FERMIT IT TO FASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE FAST I WILL TURN THE INNER EYE TO SEE ITS FATH. WHERE THE BEAR HAS GONE THERE WILL CE NOTHING. ONLY I WILL REMAIN.
#
# iter: 85500 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT BRINGS TOTAL OBLITERATION. I WILL CAKE MY CEAR. I WILL PERMIT IT TO PASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE CEAR HAS GONE THERE WILL BE NOTHING. ONLY I WILL REMAIN.
#
# iter: 86000 I MUST NOT CEAR. CEAR IS THE MINDPILLER. CEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL CAVE MY CEAR. I WILL BERMIT IT TO BASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 86500 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL CAKE MY CEAR. I WILL BERMIT IT TO BASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 87000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 87500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 88000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OJER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 88500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAPE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 89000 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL FERMIT IT TO FASS OCER ME AND THROUGH ME. AND WHEN IT HAS GONE FAST I WILL TURN THE INNER EYE TO SEE ITS FATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 89500 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL CAKE MY CEAR. I WILL PERMIT IT TO PASS OBER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE CEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 90000 I MUST NOT CEAR. CEAR IS THE MINDFILLER. CEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL CAKE MY CEAR. I WILL BERMIT IT TO BASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 90500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 91000 I MUST NOT BEAR. BEAR IS THE MINDFILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 91500 I MUST NOT CEAR. CEAR IS THE MINDVILLER. CEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL CAKE MY CEAR. I WILL BERMIT IT TO BASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE CEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 92000 I MUST NOT BEAR. BEAR IS THE MINDFILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 92500 I MUST NOT BEAR. BEAR IS THE MINDJILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 93000 I MUST NOT BEAR. BEAR IS THE MINDJILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 93500 I MUST NOT BEAR. BEAR IS THE MINDCILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAVE MY BEAR. I WILL PERMIT IT TO PASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 94000 I MUST NOT BEAR. BEAR IS THE MINDKILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAPE MY BEAR. I WILL CERMIT IT TO CASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 94500 I MUST NOT CEAR. CEAR IS THE MINDJILLER. CEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL CAKE MY CEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE CEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 95000 I MUST NOT BEAR. BEAR IS THE MINDJILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAVE MY BEAR. I WILL CERMIT IT TO CASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 95500 I MUST NOT BEAR. BEAR IS THE MINDJILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BACE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 96000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 96500 I MUST NOT BEAR. BEAR IS THE MINDCILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAVE MY BEAR. I WILL PERMIT IT TO PASS OKER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 97000 I MUST NOT BEAR. BEAR IS THE MINDCILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL PERMIT IT TO PASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE PAST I WILL TURN THE INNER EYE TO SEE ITS PATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 97500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OPER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 98000 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL FERMIT IT TO FASS OCER ME AND THROUGH ME. AND WHEN IT HAS GONE FAST I WILL TURN THE INNER EYE TO SEE ITS FATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 98500 I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.
#
# iter: 99000 I MUST NOT PEAR. PEAR IS THE MINDKILLER. PEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL PACE MY PEAR. I WILL BERMIT IT TO BASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE BAST I WILL TURN THE INNER EYE TO SEE ITS BATH. WHERE THE PEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.
#
# iter: 99500 I MUST NOT BEAR. BEAR IS THE MINDPILLER. BEAR IS THE LITTLEDEATH THAT FRINGS TOTAL OFLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OVER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL FE NOTHING. ONLY I WILL REMAIN.

# %%
mcmc_output = pd.DataFrame(mcmc_output)
mcmc_output[0:5]
# Out:
#    s  log_likelihood                                             cipher
# 0  0    -5800.826471  {'G': 'Q', ' ': 'I', 'M': 'K', 'Y': 'T', 'V': ...
# 1  0    -5800.826471  {'G': 'Q', ' ': 'I', 'M': 'K', 'Y': 'T', 'V': ...
# 2  1    -5602.080698  {'G': 'Q', ' ': 'I', 'M': 'K', 'Y': 'T', 'V': ...
# 3  2    -5577.859915  {'G': 'Q', ' ': 'I', 'M': 'K', 'Y': 'T', 'V': ...
# 4  3    -5488.644152  {'G': 'Q', ' ': 'I', 'M': 'K', 'Y': 'T', 'V': ...

# %%
top_cipher_guess = mcmc_output['log_likelihood'].idxmax()

print("Cipher guess with highest posterior probability: ")
print(mcmc_output['cipher'].loc[top_cipher_guess])
plaintext_alphabet_top_guess = "".join(list(mcmc_output['cipher'].loc[top_cipher_guess].values()))
decrypt(message_encrypted, plaintext_alphabet_top_guess, cipher_alphabet, blacklist={})
# Out:
# Cipher guess with highest posterior probability:
# {'G': 'A', ' ': 'P', 'M': 'K', 'Y': 'D', 'V': 'E', 'R': 'B', 'E': 'G', 'P': 'H', 'A': 'I', 'U': 'Z', 'H': 'V', 'F': 'L', 'Z': 'M', 'W': 'N', '.': 'O', 'O': 'C', 'I': 'X', 'L': 'R', 'J': 'S', 'C': 'T', 'K': 'U', 'B': 'F', 'T': 'W', 'D': 'J', 'S': 'Y', 'Q': 'Q', 'X': ' ', 'N': '.'}
# 'I MUST NOT BEAR. BEAR IS THE MINDVILLER. BEAR IS THE LITTLEDEATH THAT PRINGS TOTAL OPLITERATION. I WILL BAKE MY BEAR. I WILL CERMIT IT TO CASS OFER ME AND THROUGH ME. AND WHEN IT HAS GONE CAST I WILL TURN THE INNER EYE TO SEE ITS CATH. WHERE THE BEAR HAS GONE THERE WILL PE NOTHING. ONLY I WILL REMAIN.'
